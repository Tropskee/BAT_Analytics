# %%
import requests
import re
import time
from bs4 import BeautifulSoup
import pandas as pd
import os

# %% [markdown]
# ## Read URL's from .csv

# %%
data = pd.read_csv('./vehicle_html/auction_data.csv')
# Out:
#       Auction Date      Make         Model  Year  Kilometers    Miles  \
# 0          3/16/22     ACOMA      Era1970s  1975      1200.0    745.0
# 1         12/10/20     ACOMA      Era1970s  1975      1200.0    745.0
# 2          3/16/22     ACOMA      Era1970s  1975      1200.0    745.0
# 3         12/10/20     ACOMA      Era1970s  1975      1200.0    745.0
# 4          7/29/20  Era1970s  OriginFrench  1975      1200.0    745.0
# ...            ...       ...           ...   ...         ...      ...
# 72145       7/5/19     Zenos      Era2010s  2016      2735.0   1700.0
# 72146      3/20/17     Zenos      Era2010s  2015         NaN      NaN
# 72147      9/14/22    Zimmer      Era1980s  1986       804.0    500.0
# 72148       5/6/20      Ford      Era1980s  1982     77248.0  48000.0
# 72149     12/13/17    Zimmer      Era1980s  1987     22096.0  13730.0
#
#                                  Mileage Notes Sale_Status  Final Bid Price  \
# ...
